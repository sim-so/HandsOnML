# %% [markdown]
# <a href="https://colab.research.google.com/github/sim-so/HandsOnML/blob/main/16_NLPwithRNNnAttention_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 16. RNN과 어텐션을 이용한 자연어 처리  - 연습문제

# %% [markdown]
# ## 11. 최신 언어 모델 중 하나(예를 들어 BERT)로 셰익스피어가 쓴 것 같은 텍스트를 생성해보세요.

# %% [markdown]
# ### openai api
# [openai api](https://platform.openai.com/docs/guides/completion)를 이용하여 GPT 등 모델을 사용할 수 있습니다.

# %%
# !pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.3/70.3 KB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 48.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 25.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 13.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 11.2 MB/s eta 0:00:00
# ...

# %%
import os
import openai

os.environ['OPENAI_API_KEY'] = "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"
openai.api_key = os.getenv("OPENAI_API_KEY")
openai.Model.list()
# Out:
# <OpenAIObject list at 0x7f5572916220> JSON: {
#   "data": [
#     {
#       "created": 1649358449,
#       "id": "babbage",
#       "object": "model",
#       "owned_by": "openai",
#       "parent": null,
#       "permission": [
#         {
#           "allow_create_engine": false,
#           "allow_fine_tuning": false,
#           "allow_logprobs": true,
#           "allow_sampling": true,
#           "allow_search_indices": false,
#           "allow_view": true,
#           "created": 1669085501,
#           "group": null,
#           "id": "modelperm-49FUp5v084tBB49tC4z8LPH5",
#           "is_blocking": false,
#           "object": "model_permission",
#           "organization": "*"
#         }
#       ],
#       "root": "babbage"
#     },
#     {
#       "created": 1649359874,
#       "id": "davinci",
#       "object": "model",
#       "owned_by": "openai",
#       "parent": null,
#       "permission": [
#         {
#           "allow_create_engine": false,
# ...

# %%
sorted([model["id"] for model in openai.Model.list()["data"]])
# Out:
# ['ada',
#  'ada-code-search-code',
#  'ada-code-search-text',
#  'ada-search-document',
#  'ada-search-query',
#  'ada-similarity',
#  'ada:2020-05-03',
#  'babbage',
#  'babbage-code-search-code',
#  'babbage-code-search-text',
#  'babbage-search-document',
#  'babbage-search-query',
#  'babbage-similarity',
#  'babbage:2020-05-03',
#  'code-davinci-edit-001',
#  'code-search-ada-code-001',
#  'code-search-ada-text-001',
#  'code-search-babbage-code-001',
#  'code-search-babbage-text-001',
#  'curie',
#  'curie-instruct-beta',
#  'curie-search-document',
#  'curie-search-query',
#  'curie-similarity',
#  'curie:2020-05-03',
#  'cushman:2020-05-03',
#  'davinci',
#  'davinci-if:3.0.0',
#  'davinci-instruct-beta',
#  'davinci-instruct-beta:2.0.0',
#  'davinci-search-document',
#  'davinci-search-query',
#  'davinci-similarity',
#  'davinci:2020-05-03',
#  'gpt-3.5-turbo',
#  'gpt-3.5-turbo-0301',
#  'if-curie-v2',
#  'if-davinci-v2',
#  'if-davinci:3.0.0',
#  'text-ada-001',
# ...

# %%
openai.Completion.create(
    model="text-davinci-003",
    prompt="In the presence of Duke Senior and his lords,",
    max_tokens=50
)
# Out:
# <OpenAIObject text_completion id=cmpl-729xJvkQBnQqAtxHzfI8NQQT8QPYe at 0x7f5574ee2090> JSON: {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": "\n\nthe forest of Arden is an idyllic retreat from their usual courtly life, a natural setting of peace and beauty for meditation, introspection and exploration of their human condition. Duke Senior and his lords take full advantage of their temporary"
#     }
#   ],
#   "created": 1680749281,
#   "id": "cmpl-729xJvkQBnQqAtxHzfI8NQQT8QPYe",
#   "model": "text-davinci-003",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 50,
#     "prompt_tokens": 10,
#     "total_tokens": 60
#   }
# }

# %%
openai.Completion.create(
    model="text-davinci-003",
    prompt="In the presence of Duke Senior and his lords,",
    max_tokens=20,
    n=2
)
# Out:
# <OpenAIObject text_completion id=cmpl-729zu9yOwWZ1K2dhUSjQpq6DkOslt at 0x7f557288ae50> JSON: {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": "\n\nThe court was taken to a place of celebration. Joy echoed through the woods and the d"
#     },
#     {
#       "finish_reason": "length",
#       "index": 1,
#       "logprobs": null,
#       "text": " Jaques makes a speech about how all the world's a stage. He speaks about the various stages"
#     }
#   ],
#   "created": 1680749442,
#   "id": "cmpl-729zu9yOwWZ1K2dhUSjQpq6DkOslt",
#   "model": "text-davinci-003",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 40,
#     "prompt_tokens": 10,
#     "total_tokens": 50
#   }
# }

# %% [markdown]
# ### Hugging Face
# [Hugging Face](https://huggingface.co/docs/transformers/tasks/language_modeling#inference)를 활용해서 사전훈련된 모델을 불러오고, 텍스트를 생성합니다.

# %%
# !pip install transformers
# !pip install sentencepiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained('xlnet-base-cased')
model = AutoModelForCausalLM.from_pretrained("xlnet-base-cased")

# %%
prompt = "Orlando’s older brother, Oliver, treats him badly and refuses"
inputs = tokenizer(prompt, return_tensors="pt").input_ids
outputs = model.generate(inputs, max_new_tokens=100, do_sample=True, top_k=50, top_p=0.95)
print(tokenizer.batch_decode(outputs, skip_special_tokens=True))
# Out:
# ['Orlando’s older brother, Oliver, treats him badly and refuses to to to to to to to to to to to to to to to to to to to to to to to to to to to to and to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to from to to to to to and to from to to to to, to to to to to to to, to to and to to to from to to to to to from to to the to']

# %%
from transformers import pipeline

generator = pipeline("text-generation", model="xlnet-base-cased")
generator(prompt)
# Out:
# /usr/local/lib/python3.9/dist-packages/transformers/generation/utils.py:1201: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation)
#   warnings.warn(
# ...

# %%
generator = pipeline("text-generation", model="distilgpt2")
generator(prompt)
# Out:
# ...
# /usr/local/lib/python3.9/dist-packages/transformers/generation/utils.py:1201: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation)
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# /usr/local/lib/python3.9/dist-packages/transformers/generation/utils.py:1288: UserWarning: Using `max_length`'s default (50) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# ...

# %% [markdown]
# ### Llama & Alpaca
# GitHub에 공개된 모델을 불러와서 사용할 수도 있습니다.\
# Colab에서는 RAM 부족으로 Llama나 Alpaca와 같은 큰 모델을 불러올 수가 없네요. 가능한 환경에서 시도해봅시다. 😂
# - [Llama](https://github.com/facebookresearch/llama)
# - [alpaca](https://github.com/tatsu-lab/stanford_alpaca)
# - [KoAlpaca](https://github.com/Beomi/KoAlpaca)

# %%
# !pip install transformers
# !pip install sentencepiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 45.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 69.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 17.4 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 17.7 MB/s eta 0:00:00
# ...

# %%
import os
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained("EleutherAI/polyglot-ko-5.8b")
model = AutoModelForCausalLM.from_pretrained("beomi/KoAlpaca-Polyglot")
# Out:
# ...
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ### (추가) BERT 모델 사용해보기
# 문제에서 언급한 BERT 등 모델은 인코더 모델이므로 생성보다는 분류 등의 작업에 더 적합합니다.\

# %%
from transformers import AutoModelForSequenceClassification
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("smilegate-ai/kor_unsmile")
model = AutoModelForSequenceClassification.from_pretrained("smilegate-ai/kor_unsmile")

# %%
text = "으 징그러워"
inputs = tokenizer(text, return_tensors="pt")
logits = model(**inputs).logits
predicted_class_id = logits.argmax().item()
model.config.id2label[predicted_class_id]
# Out:
# '악플/욕설'

# %%
text = "사람은 참 괜찮아"
inputs = tokenizer(text, return_tensors="pt")
logits = model(**inputs).logits
predicted_class_id = logits.argmax().item()
model.config.id2label[predicted_class_id]
# Out:
# 'clean'

# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis", model="smilegate-ai/kor_unsmile")
classifier("정말 꼴보기 싫어")
# Out:
# [{'label': '악플/욕설', 'score': 0.8445074558258057}]
